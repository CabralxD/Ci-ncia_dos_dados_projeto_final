# %% [markdown]
# # Projeto Final C.D.
# ## Clusterização de jogadores do Fifa 17

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

from matplotlib import style
style.use("ggplot")
from sklearn.cluster import KMeans

# %%
# https://pythonprogramming.net/flat-clustering-machine-learning-python-scikit-learn/

# link tutorial de clusterização usando python e algoritimo de K-means

# %%
#Lendo banco de dados
dados=pd.read_excel("FUT_17_Players.xlsx", sep=',')

# %%
dados.shape
# Out:
# (14501, 78)

# %%
dados.head()
# Out:
#        id         commonName   firstName  \
# 0  190043               Pelé       Edson
# 1   20801  Cristiano Ronaldo  C. Ronaldo
# 2  158023                NaN      Lionel
# 3  168473                NaN       Franz
# 4    1109                NaN       Paolo
#
#                                       headshotImgUrl            lastName  \
# 0  https://fifa17.content.easports.com/fifa/fltOn...  Arantes Nascimento
# 1  https://fifa17.content.easports.com/fifa/fltOn...   dos Santos Aveiro
# 2  https://fifa17.content.easports.com/fifa/fltOn...               Messi
# 3  https://fifa17.content.easports.com/fifa/fltOn...         Beckenbauer
# 4  https://fifa17.content.easports.com/fifa/fltOn...             Maldini
#
#    league  nation    club                                           headshot  \
# 0    2118      54  112658  O:8:\stdClass\":3:{s:11:\"largeImgUrl\";s:148:...
# 1      53      38     243  O:8:\stdClass\":3:{s:11:\"largeImgUrl\";s:147:...
# 2      53      52     241  O:8:\stdClass\":3:{s:11:\"largeImgUrl\";s:148:...
# 3    2118      21  112658  O:8:\stdClass\":3:{s:11:\"largeImgUrl\";s:148:...
# 4    2118      27  112658  O:8:\stdClass\":3:{s:11:\"largeImgUrl\";s:146:...
#
#                                        specialImages         ...          \
# 0  O:8:\stdClass\":2:{s:15:\"largeTOTWImgUrl\";N;...         ...
# 1  O:8:\stdClass\":2:{s:15:\"largeTOTWImgUrl\";N;...         ...
# 2  O:8:\stdClass\":2:{s:15:\"largeTOTWImgUrl\";N;...         ...
# 3  O:8:\stdClass\":2:{s:15:\"largeTOTWImgUrl\";N;...         ...
# 4  O:8:\stdClass\":2:{s:15:\"largeTOTWImgUrl\";N;...         ...
#
#   rawAttributeChemistryBonus isLoan  squadPosition  itemType  discardValue  \
# 0                        NaN    NaN            NaN    player           NaN
# 1                        NaN    NaN            NaN    player           NaN
# 2                        NaN    NaN            NaN    player           NaN
# 3                        NaN    NaN            NaN    player           NaN
# 4                        NaN    NaN            NaN    player           NaN
#
#        modelName  baseId  rating          created_at          updated_at
# 0  FUTPlayerItem  190043      95 2016-09-21 16:33:58 2016-09-21 16:33:58
# 1  FUTPlayerItem   20801      94 2016-09-21 16:33:58 2016-09-21 16:33:58
# 2  FUTPlayerItem  158023      93 2016-09-21 16:33:58 2016-09-21 16:33:58
# 3  FUTPlayerItem  168473      93 2016-09-21 16:33:58 2016-09-21 16:33:58
# 4  FUTPlayerItem    1109      92 2016-09-21 16:33:58 2016-09-21 16:33:58
#
# [5 rows x 78 columns]

# %%
n=0
for h in dados.columns:
    print (h, " - coluna:",n)
    n=n+1
# Out:
# id  - coluna: 0
# commonName  - coluna: 1
# firstName  - coluna: 2
# headshotImgUrl  - coluna: 3
# lastName  - coluna: 4
# league  - coluna: 5
# nation  - coluna: 6
# club  - coluna: 7
# headshot  - coluna: 8
# specialImages  - coluna: 9
# position  - coluna: 10
# playStyle  - coluna: 11
# playStyleId  - coluna: 12
# height  - coluna: 13
# weight  - coluna: 14
# birthdate  - coluna: 15
# age  - coluna: 16
# acceleration  - coluna: 17
# aggression  - coluna: 18
# agility  - coluna: 19
# balance  - coluna: 20
# ballcontrol  - coluna: 21
# foot  - coluna: 22
# skillMoves  - coluna: 23
# crossing  - coluna: 24
# curve  - coluna: 25
# dribbling  - coluna: 26
# finishing  - coluna: 27
# freekickaccuracy  - coluna: 28
# gkdiving  - coluna: 29
# gkhandling  - coluna: 30
# gkkicking  - coluna: 31
# gkpositioning  - coluna: 32
# gkreflexes  - coluna: 33
# headingaccuracy  - coluna: 34
# interceptions  - coluna: 35
# jumping  - coluna: 36
# longpassing  - coluna: 37
# longshots  - coluna: 38
# marking  - coluna: 39
# penalties  - coluna: 40
# positioning  - coluna: 41
# potential  - coluna: 42
# reactions  - coluna: 43
# shortpassing  - coluna: 44
# shotpower  - coluna: 45
# slidingtackle  - coluna: 46
# sprintspeed  - coluna: 47
# standingtackle  - coluna: 48
# stamina  - coluna: 49
# strength  - coluna: 50
# vision  - coluna: 51
# volleys  - coluna: 52
# weakFoot  - coluna: 53
# traits  - coluna: 54
# specialities  - coluna: 55
# atkWorkRate  - coluna: 56
# defWorkRate  - coluna: 57
# playerType  - coluna: 58
# fifaAttributes  - coluna: 59
# name  - coluna: 60
# quality  - coluna: 61
# color  - coluna: 62
# isGK  - coluna: 63
# positionFull  - coluna: 64
# isSpecialType  - coluna: 65
# contracts  - coluna: 66
# fitness  - coluna: 67
# rawAttributeChemistryBonus  - coluna: 68
# isLoan  - coluna: 69
# squadPosition  - coluna: 70
# itemType  - coluna: 71
# discardValue  - coluna: 72
# modelName  - coluna: 73
# baseId  - coluna: 74
# rating  - coluna: 75
# created_at  - coluna: 76
# updated_at  - coluna: 77

# %%
#teste de clusterização básica (flat clustering)

#sklearn recebe os dados no formato numpy array
X = np.array([[1, 2],     
              [5, 8],
              [1.5, 1.8],
              [8, 8],
              [1, 0.6],
              [9, 11]])


kmeans = KMeans(n_clusters=2) #inicializa o número de clusters
kmeans.fit(X)   #"fit" da data (learning) 

centroids = kmeans.cluster_centers_ #pegando os valores das centroides do "fiting"
labels = kmeans.labels_ #labels que o programa deu 

print(centroids)
print(labels)
# Out:
# [[ 1.16666667  1.46666667]
#  [ 7.33333333  9.        ]]
# [0 1 0 1 0 1]

# %%
colors = ["g.","r.","c.","y."]

for i in range(len(X)):
    print("coordinate:",X[i], "label:", labels[i])
    plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize = 10)


plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()

#observando alguns resultados do cluster

# a lista de cores é uma lista que fornecemos para a máquina 
# escolher durante a classificação para facilitar a visualização
# neste caso só foram necessárias duas mas dependendo da quantidade
# de clusters podemos precisar de mais.

#novamente os labels são os nomes de cada grupo que o programa deu
# Out:
# coordinate: [ 1.  2.] label: 0
# coordinate: [ 5.  8.] label: 1
# coordinate: [ 1.5  1.8] label: 0
# coordinate: [ 8.  8.] label: 1
# coordinate: [ 1.   0.6] label: 0
# coordinate: [  9.  11.] label: 1

# %%
#após a primeira iteração podem ser feitas uma série de implementções
#como cluster multi dimensional e hierárquico.
#demonstrarei mais a seguir.

# %%
#Para implementar o clusterização hierárquica usaremos o algoritmo
#chamado "mean shift" (deslocamento de média) 

from sklearn.cluster import MeanShift
from sklearn.datasets.samples_generator import make_blobs

# %%
#criando um dataset para o exemplo usando make_blobs
centers = [[1,1],[5,5],[3,10]]
X, _ = make_blobs(n_samples = 500, centers = centers, cluster_std = 1)

# %%
#visualizando os dados gerados em volta dos pontos de centro:

plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
#agora queremos que a máquina reconheça os 3 clusters existentes

ms = MeanShift()
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

#inicializamos o mean shift e fazemos um "fit" do dataset.
#agora fazemos a máquina gerar os labels e os clusters points
#esses labels são diferentes do unpacked-y

# %%
#agora comparamos os centros dos clusters gerados pela análise da
#máquina com os que demos input para verificar a precisão.

print("centros de clusters estimados:")
print(cluster_centers)
n_clusters_ = len(np.unique(labels))
print("Number of estimated clusters:", n_clusters_)
print("")
print("centros de cluster original:")
print(centers)
# Out:
# centros de clusters estimados:
# [[ 5.06309607  5.03879545]
#  [ 3.06350402  9.96011936]
#  [ 1.14172798  1.10058684]]
# Number of estimated clusters: 3
#
# centros de cluster original:
# [[1, 1], [5, 5], [3, 10]]

# %%
#vê-se uma proximidade exelente entre os centros gerados e originais

colors = 10*['r.','g.','b.','c.','k.','y.','m.'] #lista de cores para o gráfico

#visualizando os dados:

for i in range(len(X)):
    plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize = 10)

plt.scatter(cluster_centers[:,0],cluster_centers[:,1],
            marker="x",color='k', s=150, linewidths = 5, zorder=10)

plt.show()

# %%
#vemos então que nosso programa conseguiu clusterizar os dados
#extremamente bem (próximo do modelo original)!

# %%
#agora testaremos o algoritmo com um modelo mais complexo em 3 dimensões

from mpl_toolkits.mplot3d import Axes3D #importando o módulo 3d

centers = [[1,1,1],[5,5,5],[3,10,10]]

X, _ = make_blobs(n_samples = 500, centers = centers, cluster_std = 1.5)



ms = MeanShift()
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

print(cluster_centers)

n_clusters_ = len(np.unique(labels))

print("Number of estimated clusters:", n_clusters_)

colors = 10*['r','g','b','c','k','y','m']

#print(colors)
#print(labels)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(len(X)):

    ax.scatter(X[i][0], X[i][1], X[i][2], c=colors[labels[i]], marker='o')


ax.scatter(cluster_centers[:,0],cluster_centers[:,1],cluster_centers[:,2],
            marker="x",color='k', s=150, linewidths = 5, zorder=10)

plt.show()
# Out:
# [[ 5.00108433  4.6479272   4.82078588]
#  [ 1.13790447  0.99653743  0.89987953]
#  [ 2.98042477  9.95743287  9.91026709]]
# Number of estimated clusters: 3

# %%
#pode ser bom rodar o código mais de uma vez e compará-lo a seus dados uma vez que o programa pode errar as vezes dado que os
#dados são gerados randomicamente (neste caso).

# %%
# para a implementação de nosso projeto teremos uma análise um tanto mais complexa pois usaremos bem mais do que 3 dimensões.

# %%
#começaremos filtrando a database pelas colunas desejadas:
#df1 = df.loc[:, ['a', 'b']]

dados_filt=dados.loc[:,["firstName", "lastName", "position", "height", "weight", "acceleration", "aggression", "agility", "ballcontrol", "crossing", "finishing", "dribbling", "gkpositioning", "gkreflexes", "longpassing", "marking", "strength", "vision", "atkWorkRate", "defWorkRate", "skillMoves", "interceptions", "slidingtackle", "gkdiving", "gkhandling"]]

# %%
dados_filt
# Out:
#          firstName             lastName position  height  weight  \
# 0            Edson   Arantes Nascimento       CF     174      70
# 1       C. Ronaldo    dos Santos Aveiro       LW     185      80
# 2           Lionel                Messi       RW     170      72
# 3            Franz          Beckenbauer       CB     181      75
# 4            Paolo              Maldini       LB     187      85
# 5           Franco               Baresi       CB     176      70
# 6           Manuel                Neuer       GK     193      92
# 7             Luis               Suárez       ST     182      85
# 8           Neymar  da Silva Santos Jr.       LW     174      68
# 9           Lothar             Matthäus      CDM     174      71
# 10           Marco           van Basten       ST     188      78
# 11      Alessandro            Del Piero       CF     174      74
# 12      Alessandro                Nesta       CB     187      79
# 13          Dennis             Bergkamp       CF     183      78
# 14          Hristo            Stoichkov       ST     178      77
# 15     Luís Filipe  Madeira Caeiro Figo       RW     180      75
# 16            Ruud       van Nistelrooy       ST     188      80
# 17          Carles      Puyol Saforcada       CB     178      80
# 18          Zlatan          Ibrahimović       ST     195      95
# 19          Gareth                 Bale       RW     183      74
# 20          Jérôme              Boateng       CB     192      90
# 21          Robert          Lewandowski       ST     185      79
# 22           Peter           Schmeichel       GK     193      92
# 23          Emilio    Butragueño Santos       ST     170      68
# 24           David      De Gea Quintana       GK     193      82
# 25            Ruud               Gullit       CM     190      88
# 26          George                 Best       RW     175      65
# 27            Alan              Shearer       ST     182      78
# 28            Ryan                Giggs       LM     179      71
# 29            Paul              Scholes       CM     171      71
# ...            ...                  ...      ...     ...     ...
# 14471       George              Jeacock       ST     178      78
# 14472         Matt                Bower       CB     198      72
# 14473        James              Gibbons       RB     172      70
# 14474         Alan                Smith       GK     185      78
# 14475         Shay               Dunlop       RB     178      69
# 14476         Gary            Armstrong       CM     180      71
# 14477         Neil           McLaughlin       ST     177      70
# 14478        James                 King       CB     177      73
# 14479       Fabian               Ehmann       GK     189      77
# 14480        Shane               Hanney       CM     182      74
# 14481        Craig            Donnellan       CM     170      71
# 14482      Ryosuke                Maeda       CM     172      65
# 14483         Josh               Koroma       CM     178      66
# 14484        Niall                Maher       GK     186      76
# 14485          Sam               Hornby       GK     188      80
# 14486        Lewis              Bamford       LB     178      69
# 14487       Jordan             Richards       CM     175      68
# 14488         Liam                Angel       CB     180      76
# 14489        Dylan              Doherty       GK     181      80
# 14490        Barry           Richardson       GK     185      77
# 14491          Sam           Ramsbottom       GK     185      80
# 14492          Ben                Kelly       GK     183      82
# 14493          Sam             Sargeant       GK     183      67
# 14494       Daniel               Devine       CM     180      76
# 14495        Dylan               McGoey       GK     185      80
# 14496         Alex             Atkinson      CAM     183      70
# 14497         Josh               Venney       CM     165      60
# 14498        Harry              Clifton       CM     180      88
# 14499          Max               Wright       RW     170      76
# 14500         Rhys               Lovett       GK     183      74
#
#        acceleration  aggression  agility  ballcontrol  crossing    ...      \
# 0                95          55       94           94        87    ...
# 1                91          63       90           92        84    ...
# 2                92          48       90           95        77    ...
# 3                83          63       80           89        64    ...
# 4                87          66       65           72        83    ...
# 5                77          79       75           89        58    ...
# 6                58          29       52           48        15    ...
# 7                88          78       86           91        77    ...
# 8                93          56       96           95        75    ...
# 9                88          93       74           87        81    ...
# 10               81          51       84           85        74    ...
# 11               86          62       86           94        87    ...
# 12               70          88       38           78        49    ...
# 13               85          84       82           89        76    ...
# 14               86          92       83           88        85    ...
# 15               82          73       83           91        88    ...
# 16               86          68       74           77        56    ...
# 17               66          91       54           67        57    ...
# 18               69          84       86           90        76    ...
# 19               93          65       77           88        87    ...
# 20               74          83       58           73        69    ...
# 21               79          80       78           87        62    ...
# 22               53          51       49           41        46    ...
# 23               92          51       86           85        74    ...
# 24               56          38       57           31        17    ...
# 25               85          67       78           87        87    ...
# 26               91          56       90           93        81    ...
# 27               81          78       71           79        77    ...
# 28               91          60       81           87        92    ...
# 29               69          88       70           87        86    ...
# ...             ...         ...      ...          ...       ...    ...
# 14471            53          33       58           41        31    ...
# 14472            51          47       42           34        20    ...
# 14473            63          79       52           25        38    ...
# 14474            49          17       34           19        19    ...
# 14475            55          52       61           31        35    ...
# 14476            71          43       53           43        41    ...
# 14477            70          52       52           45        34    ...
# 14478            67          52       40           32        30    ...
# 14479            43          19       37           20        14    ...
# 14480            69          46       54           45        38    ...
# 14481            64          44       59           44        38    ...
# 14482            73          57       56           48        39    ...
# 14483            68          33       60           50        34    ...
# 14484            29          24       28           12        11    ...
# 14485            46          17       38           16        11    ...
# 14486            68          33       59           35        38    ...
# 14487            65          27       57           47        46    ...
# 14488            52          45       58           22        20    ...
# 14489            16          24       29           17        10    ...
# 14490            25          44       38           22        11    ...
# 14491            44          22       38           11        12    ...
# 14492            42          35       36           16        18    ...
# 14493            49          18       32           17        13    ...
# 14494            67          56       62           49        39    ...
# 14495            16          15       28           13        14    ...
# 14496            54          51       44           37        28    ...
# 14497            68          34       61           40        32    ...
# 14498            65          32       57           43        34    ...
# 15                37             38        8          8
# 16                27             33       11         15
# 17                93             89       13          8
# 18                20             27       13         15
# 19                59             52       15         15
# 20                85             91        7         12
# 21                39             19       15          6
# 22                38             29       88         82
# 23                45             30        6         14
# 24                30             13       88         85
# 25                77             77        6         14
# 26                63             49        7          6
# 27                44             55        5          6
# 28                47             51       10          5
# 29                83             42        7         12
# ...              ...            ...      ...        ...
# 14471             14             18        7          8
# 14472             52             50        6          8
# 14473             51             55        6         11
# 14474             16             18       52         44
# 14475             49             47       13         11
# 14476             38             36        7          6
# 14477             45             31        8         16
# 14478             38             47        6         15
# 14479             16             15       49         37
# 14480             45             37       14          5
# 14481             42             36       12         13
# 14482             40             47        6          9
# 14483             25             39        8          7
# 14484             11             11       47         53
# 14485             12             20       50         42
# 14486             38             52       11         10
# 14487             31             29       12          6
# 14488             40             50        7         10
# 14489              9             12       47         45
# 14490             16             13       37         51
# 14491             11             11       48         41
# 14492             21             19       46         39
# 14493             18             19       46         40
# 14494             39             38        8          6
# 14495             12             12       39         46
# 14496             46             40        9         14
# 14497             28             42       13         11
# 14498             36             40        9          6
# 14499             18             30        5          8
# 14500              8             12       47         44
#
# [14501 rows x 25 columns]

# %%
#convertendo dados qualitativos em quantitativos:

dados_filt.loc[(dados_filt.atkWorkRate=="High"), "Atk"]=90
dados_filt.loc[(dados_filt.atkWorkRate=="Medium"), "Atk"]=70
dados_filt.loc[(dados_filt.atkWorkRate=="Low"), "Atk"]=50

dados_filt.loc[(dados_filt.defWorkRate=="High"), "Def"]=90
dados_filt.loc[(dados_filt.defWorkRate=="Medium"), "Def"]=70
dados_filt.loc[(dados_filt.defWorkRate=="Low"), "Def"]=50

# %%
#removendo qualitativas:
#del dados_filt["atkWorkRate"]
#del dados_filt["defWorkRate"]

# %%
n=0
for h in dados_filt.columns:
    print (h, " - coluna:",n)
    n=n+1
# Out:
# firstName  - coluna: 0
# lastName  - coluna: 1
# position  - coluna: 2
# height  - coluna: 3
# weight  - coluna: 4
# acceleration  - coluna: 5
# aggression  - coluna: 6
# agility  - coluna: 7
# ballcontrol  - coluna: 8
# crossing  - coluna: 9
# finishing  - coluna: 10
# dribbling  - coluna: 11
# gkpositioning  - coluna: 12
# gkreflexes  - coluna: 13
# longpassing  - coluna: 14
# marking  - coluna: 15
# strength  - coluna: 16
# vision  - coluna: 17
# atkWorkRate  - coluna: 18
# defWorkRate  - coluna: 19
# skillMoves  - coluna: 20
# interceptions  - coluna: 21
# slidingtackle  - coluna: 22
# gkdiving  - coluna: 23
# gkhandling  - coluna: 24
# Atk  - coluna: 25
# Def  - coluna: 26

# %%
lista_gkscore=[]
for h in range(len(dados_filt)):
    w=dados_filt.iloc[h][12]
    j=dados_filt.iloc[h][24]
    o=dados_filt.iloc[h][13]
    u=dados_filt.iloc[h][23]
    g=int((w+j+o+u)/4)
    lista_gkscore.append(g)

# %%
lista_def=[]
for h in range(len(dados_filt)):
    w=dados_filt.iloc[h][15]
    j=dados_filt.iloc[h][21]
    o=dados_filt.iloc[h][22]
    g=int((w+j+o)/3)
    lista_def.append(g)

# %%
lista_of=[]
for h in range(len(dados_filt)):
    w=dados_filt.iloc[h][9]
    j=dados_filt.iloc[h][10]
    o=dados_filt.iloc[h][11]
    g=int((w+j+o)/3)
    lista_of.append(g)

# %%
print(len(lista_gkscore))
print(len(lista_def))
print(len(lista_of))
#print(lista)
#com está lista, que será uma das variáveis do nosso cluster podemos identificar os goleiros.
# Out:
# 14501
# 14501
# 14501

# %%
#https://jakevdp.github.io/PythonDataScienceHandbook/05.11-k-means.html

# %%
#adicionando a coluna "gkscore"
dados_filt['gkscore']=(dados_filt['gkdiving']+dados_filt['gkreflexes']+dados_filt['gkhandling']+dados_filt['gkpositioning'])/4
dados_filt['offensive_score']=(dados_filt['dribbling']+dados_filt['finishing']+dados_filt['crossing'])/3
dados_filt['defensive_score']=(dados_filt['marking']+dados_filt['slidingtackle']+dados_filt['interceptions'])/3

# %%
dados_filt.columns
# Out:
# Index(['firstName', 'lastName', 'position', 'height', 'weight', 'acceleration',
#        'aggression', 'agility', 'ballcontrol', 'crossing', 'finishing',
#        'dribbling', 'gkpositioning', 'gkreflexes', 'longpassing', 'marking',
#        'strength', 'vision', 'atkWorkRate', 'defWorkRate', 'skillMoves',
#        'interceptions', 'slidingtackle', 'gkdiving', 'gkhandling', 'Atk',
#        'Def', 'gkscore', 'offensive_score', 'defensive_score'],
#       dtype='object')

# %%
dados_filt
# Out:
#          firstName             lastName position  height  weight  \
# 0            Edson   Arantes Nascimento       CF     174      70
# 1       C. Ronaldo    dos Santos Aveiro       LW     185      80
# 2           Lionel                Messi       RW     170      72
# 3            Franz          Beckenbauer       CB     181      75
# 4            Paolo              Maldini       LB     187      85
# 5           Franco               Baresi       CB     176      70
# 6           Manuel                Neuer       GK     193      92
# 7             Luis               Suárez       ST     182      85
# 8           Neymar  da Silva Santos Jr.       LW     174      68
# 9           Lothar             Matthäus      CDM     174      71
# 10           Marco           van Basten       ST     188      78
# 11      Alessandro            Del Piero       CF     174      74
# 12      Alessandro                Nesta       CB     187      79
# 13          Dennis             Bergkamp       CF     183      78
# 14          Hristo            Stoichkov       ST     178      77
# 15     Luís Filipe  Madeira Caeiro Figo       RW     180      75
# 16            Ruud       van Nistelrooy       ST     188      80
# 17          Carles      Puyol Saforcada       CB     178      80
# 18          Zlatan          Ibrahimović       ST     195      95
# 19          Gareth                 Bale       RW     183      74
# 20          Jérôme              Boateng       CB     192      90
# 21          Robert          Lewandowski       ST     185      79
# 22           Peter           Schmeichel       GK     193      92
# 23          Emilio    Butragueño Santos       ST     170      68
# 24           David      De Gea Quintana       GK     193      82
# 25            Ruud               Gullit       CM     190      88
# 26          George                 Best       RW     175      65
# 27            Alan              Shearer       ST     182      78
# 28            Ryan                Giggs       LM     179      71
# 29            Paul              Scholes       CM     171      71
# ...            ...                  ...      ...     ...     ...
# 14497            68          34       61           40        32
# 14498            65          32       57           43        34
# 14499            65          28       69           36        43
# 14500            36          12       48           19        12
#
#             ...        skillMoves  interceptions  slidingtackle  gkdiving  \
# 0           ...                 5             61             42        15
# 1           ...                 5             29             23         7
# 2           ...                 4             22             26         6
# 3           ...                 3             96             91        14
# 4           ...                 2             94             94        10
# 5           ...                 2             95             92         6
# 6           ...                 1             30             11        89
# 7           ...                 4             41             38        27
# 8           ...                 5             36             33         9
# 9           ...                 3             91             90        15
# 10          ...                 3             45             21         7
# 11          ...                 3             43             34        12
# 12          ...                 2             89             92         8
# 13          ...                 4             21             16         9
# 14          ...                 4             56             47        11
# 15          ...                 4             37             38         8
# 16          ...                 3             27             33        11
# 17          ...                 2             93             89        13
# 18          ...                 4             20             27        13
# 19          ...                 4             59             52        15
# 20          ...                 2             85             91         7
# 21          ...                 3             39             19        15
# 22          ...                 1             38             29        88
# 23          ...                 3             45             30         6
# 24          ...                 1             30             13        88
# 25          ...                 4             77             77         6
# 26          ...                 4             63             49         7
# 27          ...                 3             44             55         5
# 28          ...                 3             47             51        10
# 29          ...                 3             83             42         7
# ...         ...               ...            ...            ...       ...
# 14471       ...                 3             14             18         7
# 14472       ...                 2             52             50         6
# 14473       ...                 2             51             55         6
# 14474       ...                 1             16             18        52
# 14475       ...                 2             49             47        13
# 14476       ...                 2             38             36         7
# 14477       ...                 2             45             31         8
# 14478       ...                 2             38             47         6
# 14479       ...                 1             16             15        49
# 14480       ...                 2             45             37        14
# 14481       ...                 2             42             36        12
# 14482       ...                 2             40             47         6
# 14483       ...                 2             25             39         8
# 14484       ...                 1             11             11        47
# 14485       ...                 1             12             20        50
# 14486       ...                 2             38             52        11
# 14487       ...                 2             31             29        12
# 14488       ...                 2             40             50         7
# 14489       ...                 1              9             12        47
# 14490       ...                 1             16             13        37
# 14491       ...                 1             11             11        48
# 14492       ...                 1             21             19        46
# 14493       ...                 1             18             19        46
# 14494       ...                 2             39             38         8
# 14495       ...                 1             12             12        39
# 14496       ...                 3             46             40         9
# 14497       ...                 2             28             42        13
# 14498       ...                 2             36             40         9
# 14499       ...                 3             18             30         5
# 14500       ...                 1              8             12        47
#
#        gkhandling   Atk   Def  gkscore offensive_score defensive_score
# 0              12  90.0  50.0    11.50       90.333333       50.333333
# 1              11  90.0  50.0    10.75       90.000000       24.666667
# 2              11  70.0  70.0     9.75       89.666667       20.333333
# 3              14  90.0  70.0    12.50       66.333333       93.666667
# 4               6  70.0  90.0     9.50       68.666667       94.333333
# 5               8  70.0  70.0     8.25       47.666667       93.666667
# 6              90  70.0  70.0    89.75       19.333333       17.000000
# 7              25  90.0  70.0    30.50       85.666667       36.333333
# 8               9  90.0  70.0    11.00       86.666667       30.000000
# 9               6  90.0  90.0     9.25       77.666667       89.333333
# 10              9  70.0  70.0     9.50       83.000000       30.333333
# 11              9  50.0  50.0    10.00       91.333333       37.666667
# 12              9  70.0  90.0    10.50       41.666667       91.666667
# 1       C. Ronaldo    dos Santos Aveiro       LW     185      80
# 26          George                 Best       RW     175      65
# 2           Lionel                Messi       RW     170      72
# 19          Gareth                 Bale       RW     183      74
# 28            Ryan                Giggs       LM     179      71
# 14          Hristo            Stoichkov       ST     178      77
# 8           Neymar  da Silva Santos Jr.       LW     174      68
# 39        Gheorghe                 Hagi      CAM     172      68
# 108    Paulo Jorge     dos Santos Futre       LW     175      74
# 15     Luís Filipe  Madeira Caeiro Figo       RW     180      75
# 159          Paulo               Dybala       ST     176      73
# 106          James            Rodríguez      CAM     180      75
# 75         Antoine            Griezmann       ST     176      67
# 74           Kevin            De Bruyne      CAM     181      76
# 83      Gianfranco                 Zola       CF     168      67
# 7             Luis               Suárez       ST     182      85
# 87           Arjen               Robben       RM     180      80
# 23          Emilio    Butragueño Santos       ST     170      68
# 13          Dennis             Bergkamp       CF     183      78
# 72            Eden               Hazard       LM     173      74
# 25            Ruud               Gullit       CM     190      88
# 18          Zlatan          Ibrahimović       ST     195      95
# 73           Marco                 Reus       LM     180      75
# 158          Riyad               Mahrez       RM     179      62
# 100          Ángel             Di María       RW     180      75
# 102         Alexis              Sánchez       LW     169      62
# 117         Landon              Donovan       CF     173      73
# 168          Hatem             Ben Arfa      CAM     178      74
# ...            ...                  ...      ...     ...     ...
# 12624      Quentin                Braat       GK     192      84
# 12615     Luthando              Sixhaso       GK     192      82
# 13973        Ayumi              Niekawa       GK     195      90
# 14324        Felix          Gschossmann       GK     183      75
# 12634      Kentaro                 Seki       GK     178      76
# 6742        Takuto              Hayashi       GK     188      87
# 14500         Rhys               Lovett       GK     183      74
# 12290      Ricardo              Kieboom       GK     187      83
# 13955     Kristian               Rutlin       GK     181      66
# 11331          Aly                Keita       GK     185      75
# 1005         Denys                Boyko       GK     194      82
# 13274     Akishige               Kaneda       GK     184      71
# 14259      Ataberk               Gürgen       GK     185      75
# 11536        Louis               Bostyn       GK     195      86
# 13258      Florian              Escales       GK     182      78
# 13273      Ryuichi             Kamiyama       GK     188      94
# 14148    Baboucarr                 Gaye       GK     194      87
# 14489        Dylan              Doherty       GK     181      80
# 13524       Stefan              Hagerup       GK     187      79
# 13073      Clément                 Diop       GK     185      75
# 12623    Sebastián                Duque       GK     183      78
# 12689        Chris                  Day       GK     188      85
# 5177       Philipp            Tschauner       GK     196      93
# 13243        James              Aguirre       GK     180      70
# 13208      Dominik              Reimann       GK     185      81
# 14112        Naoki                Hatta       GK     185      80
# 14240       Takaya             Kurokawa       GK     184      78
# 13442       Xavier              Lenogue       GK     194      84
# 14136       Martin             Kompalla       GK     186      82
# 13304       Gaëtan               Coucke       GK     187      77
#
#        acceleration  aggression  agility  ballcontrol  crossing  \
# 11               86          62       86           94        87
# 0                95          55       94           94        87
# 1                91          63       90           92        84
# 26               91          56       90           93        81
# 2                92          48       90           95        77
# 19               93          65       77           88        87
# 28               91          60       81           87        92
# 14               86          92       83           88        85
# 8                93          56       96           95        75
# 39               84          55       81           88        90
# 108              88          43       94           91        83
# 15               82          73       83           91        88
# 159              91          48       91           91        78
# 106              77          65       82           85        88
# 75               87          69       90           86        82
# 74               76          68       78           86        90
# 83               88          62       85           90        82
# 7                88          78       86           91        77
# 87               87          47       89           89        80
# 23               92          51       86           85        74
# 13               85          84       82           89        76
# 72               93          54       92           90        80
# 25               85          67       78           87        87
# 18               69          84       86           90        76
# 73               89          47       87           85        83
# 158              86          39       92           88        83
# 100              86          76       90           87        90
# 102              88          80       90           86        80
# 117              86          66       82           85        83
# 168              84          67       85           86        78
# ...             ...         ...      ...          ...       ...
# 12624            22          27       32           14        12
# 12615            23          29       27            9        11
# 13973            33          26       29           19        12
# 14324            16          24       37           17        11
# 12634            29          28       27           15        11
# 6742             25          24       38           15        12
# 14500            36          12       48           19        12
# 12290            21          26       28           12        10
# 13955            31          18       22           17        10
# 11331            20          28       36           12        10
# 1005             49          38       60           12        11
# 13274            30          20       41           12         9
# 14259            31          21       25           16        11
# 11536            31          34       37           13        19
# 13258            19          19       23           17        11
# 13273            20          23       21           11         8
# 14148            18          18       22           15        11
# 14489            16          24       29           17        10
# 13524            33          22       23           18        13
# 13073            53          22       24           18         6
# 12623            32          19       23           13        10
# 12689            11          23       20           16         8
# 5177             38          27       36           22         7
# 13243            38          22       40           20         9
# 13208            44          18       49           14         9
# 14112            31          22       25           12        12
# 14240            27          16       27           15        10
# 13442            46          13       38           13         7
# 14136            36          20       44            9         8
# 13304            23          24       28           13         8
#
#             ...        skillMoves  interceptions  slidingtackle  gkdiving  \
# 11          ...                 3             43             34        12
# 0           ...                 5             61             42        15
# 1           ...                 5             29             23         7
# 26          ...                 4             63             49         7
# 2           ...                 4             22             26         6
# 19          ...                 4             59             52        15
# 28          ...                 3             47             51        10
# 14          ...                 4             56             47        11
# 8           ...                 5             36             33         9
# 39          ...                 4             44             41        11
# 108         ...                 4             21             26         7
# 15          ...                 4             37             38         8
# 159         ...                 4             24             20         5
# 106         ...                 4             55             30        15
# 75          ...                 4             35             11        14
# 74          ...                 4             52             40        15
# 83          ...                 3             22             20        15
# 7           ...                 4             41             38        27
# 87          ...                 4             39             26        10
# 23          ...                 3             45             30         6
# 13          ...                 4             21             16         9
# 72          ...                 4             41             22        11
# 25          ...                 4             77             77         6
# 18          ...                 4             20             27        13
# 73          ...                 4             50             46        12
# 158         ...                 5             38             21        15
# 100         ...                 5             38             56        10
# 102         ...                 4             42             35        10
# 117         ...                 3             42             32        10
# 168         ...                 5             40             23        12
# ...         ...               ...            ...            ...       ...
# 12624       ...                 1             11             11        62
# 12615       ...                 1              9             22        60
# 13973       ...                 1              9             14        58
# 14324       ...                 1              9             11        54
# 12634       ...                 1             10             14        54
# 6742        ...                 1             10             13        63
# 14500       ...                 1              8             12        47
# 12290       ...                 1             10             10        66
# 13955       ...                 1             10             10        44
# 11331       ...                 1             10             11        74
# 1005        ...                 1             12             11        83
# 11331          53  70.0  70.0    61.75        8.333333        8.666667
# 1005           69  70.0  70.0    77.50        8.333333       10.666667
# 13274          56  70.0  70.0    56.75        8.333333        8.000000
# 14259          61  70.0  70.0    54.25        8.333333        6.666667
# 11536          64  70.0  70.0    60.50        8.333333       15.000000
# 13258          55  70.0  70.0    57.50        8.000000       10.333333
# 13273          46  70.0  70.0    56.50        8.000000        8.000000
# 14148          50  70.0  70.0    54.00        8.000000        9.000000
# 14489          45  70.0  70.0    45.75        8.000000       10.000000
# 13524          59  70.0  70.0    55.75        8.000000        9.000000
# 13073          53  70.0  70.0    57.00        8.000000       10.666667
# 12623          56  70.0  70.0    59.50        7.666667       10.333333
# 12689          54  70.0  70.0    56.75        7.666667       13.000000
# 5177           68  70.0  70.0    68.25        7.666667       12.000000
# 13243          54  70.0  70.0    57.25        7.666667       11.666667
# 13208          52  70.0  70.0    55.75        7.333333        8.666667
# 14112          48  70.0  70.0    52.75        7.333333        8.666667
# 14240          52  70.0  70.0    50.25        7.333333       10.666667
# 13442          54  70.0  70.0    54.50        7.000000       11.666667
# 14136          48  70.0  70.0    52.00        7.000000        8.666667
# 13304          54  70.0  70.0    56.25        6.666667       13.000000
#
# [14501 rows x 30 columns]

# %%
#ex:
#df['diff_A_B'] = df['A'] - df['B']

# %%
#dados_filt["gk"]=lista

# %%
lista_cluster=[]
for h in range(len(dados_filt)):
    w=[dados_filt.loc[h]['offensive_score'], dados_filt.loc[h]['defensive_score'], dados_filt.loc[h]['gkscore']]
    lista_cluster.append(w)

# %%
print(lista_cluster)
# Out:
# [[90.333333333333329, 50.333333333333336, 11.5], [90.0, 24.666666666666668, 10.75], [89.666666666666671, 20.333333333333332, 9.75], [66.333333333333329, 93.666666666666671, 12.5], [68.666666666666671, 94.333333333333329, 9.5], [47.666666666666664, 93.666666666666671, 8.25], [19.333333333333332, 17.0, 89.75], [85.666666666666671, 36.333333333333336, 30.5], [86.666666666666671, 30.0, 11.0], [77.666666666666671, 89.333333333333329, 9.25], [83.0, 30.333333333333332, 9.5], [91.333333333333329, 37.666666666666664, 10.0], [41.666666666666664, 91.666666666666671, 10.5], [85.0, 18.0, 10.5], [87.333333333333329, 45.666666666666664, 9.25], [86.0, 34.0, 9.75], [74.666666666666671, 25.333333333333332, 10.5], [47.0, 91.0, 10.0], [84.333333333333329, 20.666666666666668, 12.25], [87.666666666666671, 54.0, 10.25], [56.666666666666664, 89.0, 7.5], [79.333333333333329, 27.666666666666668, 9.75], [39.666666666666664, 29.333333333333332, 87.0], [85.0, 32.0, 10.75], [14.333333333333334, 18.666666666666668, 87.0], [84.333333333333329, 77.666666666666671, 11.25], [90.0, 56.333333333333336, 6.5], [81.0, 40.0, 7.25], [87.333333333333329, 41.333333333333336, 6.25], [79.333333333333329, 62.333333333333336, 10.5], [48.333333333333336, 87.666666666666671, 10.0], [45.333333333333336, 89.0, 10.75], [83.0, 42.666666666666664, 9.0], [10.333333333333334, 15.666666666666666, 87